# %%
# %sql
-- catalog creation
CREATE CATALOG IF NOT EXISTS de_project_catalog

# %%
# %sql
-- schema bronze creation
CREATE SCHEMA IF NOT EXISTS de_project_catalog.olist_bronze;

-- schema silver creation
CREATE SCHEMA IF NOT EXISTS de_project_catalog.olist_silver;

-- schema gold layer
CREATE SCHEMA IF NOT EXISTS de_project_catalog.olist_gold;

# %%
# %sql

-- volume for bronze
CREATE VOLUME IF NOT EXISTS de_project_catalog.olist_bronze.raw_data;

-- volume for silver
CREATE VOLUME IF NOT EXISTS de_project_catalog.olist_silver.cleaned_data;

-- volume for gold
CREATE VOLUME IF NOT EXISTS de_project_catalog.olist_gold.analytics_data;

# %%
# Creating raw_source Folder 
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/raw_source")

#creating folders inside raw_sorce
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/raw_source/orders")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/raw_source/customers")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/raw_source/order_items")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/raw_source/payments")

# creating bronze folder
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/bronze")

#creating folders in bronze folder
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/bronze/orders")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/bronze/customers")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/bronze/order_items")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_bronze/raw_data/bronze/payments")

# %%
#creating folders iinside olist_silver volume
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_silver/cleaned_data/orders")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_silver/cleaned_data/customers")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_silver/cleaned_data/order_items")
dbutils.fs.mkdirs("/Volumes/de_project_catalog/olist_silver/cleaned_data/payments")
